# %%
import os 
import pickle 
from natsort import natsorted

def load_data_as_dict(directory_path):
    """
    Return pickle file in directory_path as a list. 
    Also returns a list of all the unique id's in the dataset. 
    Why do we need unique id? 
        Lets say a task is randomly mapped 100 times. 
        All the 100 data (dict in pickle file) will have the same id. 
        So it is easier to retrieve all the mapping for a single task
    """
    entries = os.listdir(directory_path)
    files = natsorted([entry for entry in entries if os.path.isfile(os.path.join(directory_path, entry))])

    list_of_dicts = []
    list_of_uuids = []

    for file_name in files:
        file_path = os.path.join(directory_path, file_name)

        with open(file_path, 'rb') as file:
            data_dict = pickle.load(file)
            list_of_dicts.append(data_dict)

            uuid = data_dict['task_dag'].id

            if uuid not in list_of_uuids:
                list_of_uuids.append(uuid)

    return list_of_dicts, list_of_uuids

# %%
dataset, _ = load_data_as_dict('data/task_from_graph')

# %%
import networkx as nx
dataset[0]['task_dag'].graph
def get_node_attribute_types(G):
    attribute_types = {}

    for node, attributes in G.nodes(data=True):
        for attr_name, attr_value in attributes.items():
            attribute_types[attr_name] = type(attr_value)

    return attribute_types

get_node_attribute_types(dataset[0]['task_dag'].graph)
# Out:
# {'delay': int}

# %%
import pandas as pd 
df = pd.DataFrame(dataset)
df['network_processing_time'] = pd.to_numeric(df['network_processing_time'])
df['network_processing_time'].describe()
# Out:
# count    81200.000000
# mean      2040.257993
# std        354.290683
# min       1027.000000
# 25%       1738.000000
# 50%       2033.000000
# 75%       2322.000000
# max       3672.000000
# Name: network_processing_time, dtype: float64

# %%
import os 
from torch_geometric.utils import from_networkx
from torch_geometric.data import Data, Batch
import torch

def convert_graph_to_tensor(graph, latency):
    # graph_tensor = from_networkx(graph, group_node_attrs=['weight', 'type'])
    graph_tensor = from_networkx(graph)
    graph_tensor.y = torch.tensor([latency])
    # graph_tensor.x[:, 0] = graph_tensor.x[:, 0] / 100
    # del graph_tensor.pos
    return graph_tensor

def convert_edge_index(edge_index, num_of_tasks):
    # Convertts 'Start' to 0
    # Convertts 'Exit' to num_of_tasks
    converted_edge_index = []
    node_mapping = {'Start': 0, 'Exit': num_of_tasks}

    for src, dest in edge_index:
        if src == 'Start':
            src = node_mapping[src]

        if dest == 'Exit':
            dest = node_mapping[dest]

        converted_edge_index.append((int(src), int(dest)))

    return converted_edge_index

def convert_directed_to_undirected_edge_index(edge_index):
    undirected_edge_index = []

    for src, dest in edge_index:
        undirected_edge_index.append((src, dest))
        undirected_edge_index.append((dest, src))

    return undirected_edge_index

def visualize_graph(graph, is_unidirected=False):
    import matplotlib.pyplot as plt
    from torch_geometric.utils import to_networkx
    import networkx as nx

    graph = to_networkx(graph, to_undirected=is_unidirected)

    pos = nx.spring_layout(graph, seed=42)
    nx.draw(graph, pos, with_labels=True)
    plt.show()


directory_path = 'data/task_from_graph_tensor'

if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"Directory '{directory_path}' created successfully.")
else:
    print(f"Directory '{directory_path}' already exists.")

def add_node_attributes(graph):
    attribute_name = 'node_type'
    one_hot_mapping = {'Start': [1.0, 0.0, 0.0], 'Exit': [0.0, 0.0, 1.0], 'processing': [0.0, 1.0, 0.0]}
    attributes = {node: torch.tensor(one_hot_mapping['processing']) if node not in ['Start', 'Exit'] else torch.tensor(one_hot_mapping[node]) for node in graph.nodes()}
    nx.set_node_attributes(graph, attributes, attribute_name)

for idx, data in enumerate(dataset):
    
    task_dag = data['task_dag']
    task_processing_time = float(data['network_processing_time'])
    target_value = torch.tensor([task_processing_time]).float()

    task_graph = task_dag.graph
    add_node_attributes(task_graph)

    edge_index = list(task_graph.edges)
    
    total_tasks = len(task_graph.nodes)
    last_task = len(task_graph.nodes) - 1

    graph_tensor = from_networkx(task_graph)
    
    # To remove unnecessary node attributes
    data = Data(
        edge_index=graph_tensor.edge_index, 
        y=torch.tensor([float(target_value)]), 
        x=graph_tensor.node_type
    )

    if idx % 100 == 0:
        print(f"{idx}th graph data ->\t {data}")


    # print(data.x.shape)
    # break
    torch.save(data, f'{directory_path}/graph_{idx}.pt')
# Out:
# Directory 'data/task_from_graph_tensor' already exists.
# 0th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 100th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 200th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 300th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 400th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 500th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 600th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 700th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 800th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 900th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 1000th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 1100th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 1200th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 1300th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 1400th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 1500th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 1600th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 1700th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 1800th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 1900th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 2000th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 2100th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 2200th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 2300th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 2400th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 2500th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 2600th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 2700th graph data ->	 Data(x=[9, 3], edge_index=[2, 19], y=[1])
# 2800th graph data ->	 Data(x=[9, 3], edge_index=[2, 18], y=[1])
# 2900th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 3000th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 3100th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 3200th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 3300th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 3400th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 3500th graph data ->	 Data(x=[9, 3], edge_index=[2, 17], y=[1])
# 3600th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 3700th graph data ->	 Data(x=[9, 3], edge_index=[2, 9], y=[1])
# 3800th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 3900th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 4000th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 4100th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 4200th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 4300th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 4400th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 4500th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 4600th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 4700th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 4800th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 4900th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 5000th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 5100th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 5200th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 5300th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 5400th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 5500th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 5600th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 5700th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 5800th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 5900th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 6000th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 6100th graph data ->	 Data(x=[9, 3], edge_index=[2, 17], y=[1])
# 6200th graph data ->	 Data(x=[9, 3], edge_index=[2, 18], y=[1])
# 6300th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 6400th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 6500th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 6600th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 6700th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 6800th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 6900th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 7000th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 7100th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 7200th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 7300th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 7400th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 7500th graph data ->	 Data(x=[9, 3], edge_index=[2, 17], y=[1])
# 7600th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 7700th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 7800th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 7900th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 8000th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 8100th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 8200th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 8300th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 8400th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 8500th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 8600th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 8700th graph data ->	 Data(x=[9, 3], edge_index=[2, 9], y=[1])
# 8800th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 8900th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 9000th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 9100th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 9200th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 9300th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 9400th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 9500th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 9600th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 9700th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 9800th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 9900th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 10000th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 10100th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 10200th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 10300th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 10400th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 10500th graph data ->	 Data(x=[9, 3], edge_index=[2, 17], y=[1])
# 10600th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 10700th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 10800th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 10900th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 11000th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 11100th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 11200th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 11300th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 11400th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 11500th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 11600th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 11700th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 11800th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 11900th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 12000th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 12100th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 12200th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 12300th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 12400th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 12500th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 12600th graph data ->	 Data(x=[9, 3], edge_index=[2, 9], y=[1])
# 12700th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 12800th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 12900th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 13000th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 13100th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 13200th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 13300th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 13400th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 13500th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 13600th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 13700th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 13800th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 13900th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 14000th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 14100th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 14200th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 14300th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 14400th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 14500th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 14600th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 14700th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 14800th graph data ->	 Data(x=[9, 3], edge_index=[2, 19], y=[1])
# 14900th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 15000th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 15100th graph data ->	 Data(x=[9, 3], edge_index=[2, 17], y=[1])
# 15200th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 15300th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 15400th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 15500th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 15600th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 15700th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 15800th graph data ->	 Data(x=[9, 3], edge_index=[2, 9], y=[1])
# 15900th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 16000th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 16100th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 16200th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 16300th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 16400th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 16500th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 16600th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 16700th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 16800th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 16900th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
# 17000th graph data ->	 Data(x=[9, 3], edge_index=[2, 17], y=[1])
# 17100th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 17200th graph data ->	 Data(x=[9, 3], edge_index=[2, 15], y=[1])
# 17300th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 17400th graph data ->	 Data(x=[9, 3], edge_index=[2, 9], y=[1])
# 17500th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 17600th graph data ->	 Data(x=[9, 3], edge_index=[2, 13], y=[1])
# 17700th graph data ->	 Data(x=[9, 3], edge_index=[2, 12], y=[1])
# 17800th graph data ->	 Data(x=[9, 3], edge_index=[2, 14], y=[1])
# 17900th graph data ->	 Data(x=[9, 3], edge_index=[2, 11], y=[1])
# 18000th graph data ->	 Data(x=[9, 3], edge_index=[2, 16], y=[1])
# 18100th graph data ->	 Data(x=[9, 3], edge_index=[2, 10], y=[1])
#